# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
type_x = ['10', '20', '50', '100']
type_time = ['5','10','20', '50', '100']

# %%
time =100
list_x = [np.array(pd.read_csv(f'E:/Learning/Docker_basic/basic_kafka/kltn/experiments/respond_latency/{x}_{time}s.csv')['latency'])\
                            for x in type_x]
avg_x = [np.average(x) for x in list_x]
# Out:
# [0.9207983493804932, 0.8279804587364197, 0.861797194480896, 0.8338055086135864]

# %%
time =10
list_x = [np.array(pd.read_csv(f'E:/Learning/Docker_basic/basic_kafka/kltn/experiments/respond_latency/{x}_{time}s.csv')['latency'])\
                            for x in type_x]
avg_x = [np.average(x) for x in list_x]

fig, axs = plt.subplots(2, 2, figsize=(12, 13))

# Vẽ từng boxplot trong từng subplot
for i, ax in enumerate(axs.flatten()):
    sns.boxplot(list_x[i], ax=ax)
    ax.set_title(f'Boxplot phân bố thời gian thực thi với {type_x[i]} request')
    ax.set_ylabel('Latency (second)')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
